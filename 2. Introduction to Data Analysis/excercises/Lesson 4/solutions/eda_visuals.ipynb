# %% [markdown]
# # EDA with Visuals
# Create visualizations to answer the quiz questions below this notebook. Use the `winequality_edited.csv` dataset, which you should've created  in the previous concept: *Appending Data (cont.)*.

# %%
# Load dataset
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

wine_df = pd.read_csv("winequality_edited.csv")

wine_df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur-dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %% [markdown]
# ### Histograms for Various Features

# %%
ax = wine_df[wine_df['color'] == 'red'].hist(bins = 50, figsize = (10, 10), alpha = 0.5)
wine_df[wine_df['color'] == 'white'].hist(ax = ax, bins = 50, alpha = 0.5)
plt.show()

# %%
sns.pairplot(wine_df, kind = "scatter", hue = "color", markers = ["o", "s"], palette = "Set2")

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-34af4a8371a5> in <module>()
#       1
# ----> 2 pd.plotting.scatter_matrix(wine_df[wine_df['color'] == 'red'], ax = axes[1], alpha = 0.5)
#       3 pd.plotting.scatter_matrix(wine_df[wine_df['color'] == 'white'], ax = axes[1], alpha = 0.5)
#       4 plt.show()
#
# /opt/conda/lib/python3.6/site-packages/pandas/plotting/_misc.py in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwds)
#      82     for i, a in zip(lrange(n), df.columns):
#      83         for j, b in zip(lrange(n), df.columns):
# ---> 84             ax = axes[i, j]
#      85
#      86             if i == j:
#
# IndexError: too many indices for array

# %% [markdown]
# ### Scatterplots of Quality Against Various Features

# %%
wine_df[wine_df['color'] == 'red'].plot.scatter(x = 'pH', y = 'quality')
